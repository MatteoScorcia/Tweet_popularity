# %%
import numpy as np
import pandas as pd

# %%
s = pd.Series([1, 3, 5, np.nan, 6, 8])

# %%
s
# Out:
# 0    1.0
# 1    3.0
# 2    5.0
# 3    NaN
# 4    6.0
# 5    8.0
# dtype: float64

# %%
dates = pd.date_range('20130101', periods=6)

# %%
dates
# Out:
# DatetimeIndex(['2013-01-01', '2013-01-02', '2013-01-03', '2013-01-04',
#                '2013-01-05', '2013-01-06'],
#               dtype='datetime64[ns]', freq='D')

# %%
df = pd.DataFrame(np.random.randn(6, 4), index=dates, columns=list('ABCD'))

# %%
df
# Out:
#                    A         B         C         D
# 2013-01-01  1.606217  0.855340  0.511767  0.692767
# 2013-01-02 -0.804893  0.612661 -1.261758 -0.128382
# 2013-01-03 -0.217233 -0.598846  0.008532  0.576786
# 2013-01-04 -0.661728  0.887145 -0.124807  1.468001
# 2013-01-05  0.642605  0.593016  1.015690  1.641959
# 2013-01-06 -0.888369 -1.403047 -1.007927 -0.348572

# %%
df2 = pd.DataFrame({'A': 1.,
   ...:                     'B': pd.Timestamp('20130102'),
   ...:                     'C': pd.Series(1, index=list(range(4)), dtype='float32'),
   ...:                     'D': np.array([3] * 4, dtype='int32'),
   ...:                     'E': pd.Categorical(["test", "train", "test", "train"]),
   ...:                     'F': 'foo'})
   ...:

# %%
df2
# Out:
#      A          B    C  D      E    F
# 0  1.0 2013-01-02  1.0  3   test  foo
# 1  1.0 2013-01-02  1.0  3  train  foo
# 2  1.0 2013-01-02  1.0  3   test  foo
# 3  1.0 2013-01-02  1.0  3  train  foo

# %%
df2.B
# Out:
# 0   2013-01-02
# 1   2013-01-02
# 2   2013-01-02
# 3   2013-01-02
# Name: B, dtype: datetime64[ns]

# %%
df2.describe()
# Out:
#          A    C    D
# count  4.0  4.0  4.0
# mean   1.0  1.0  3.0
# std    0.0  0.0  0.0
# min    1.0  1.0  3.0
# 25%    1.0  1.0  3.0
# 50%    1.0  1.0  3.0
# 75%    1.0  1.0  3.0
# max    1.0  1.0  3.0

# %%
df = pd.read_csv("../dataset/prova.csv")

# %%
df
# Out:
#           screen_name                 date  \
# 0   Orietta's Recipes  2020-01-17 18:09:56
# 1   Orietta's Recipes  2020-01-17 11:57:39
# 2   Orietta's Recipes  2020-01-17 07:51:15
# 3   Orietta's Recipes  2020-01-16 17:28:59
# 4   Orietta's Recipes  2020-01-16 13:51:03
# 5   Orietta's Recipes  2020-01-16 11:46:01
# 6   Orietta's Recipes  2020-01-16 07:36:10
# 7   Orietta's Recipes  2020-01-15 18:24:25
# 8   Orietta's Recipes  2020-01-15 11:39:56
# 9   Orietta's Recipes  2020-01-15 07:38:50
# 10  Orietta's Recipes  2020-01-14 17:59:22
# 11  Orietta's Recipes  2020-01-14 11:52:32
# 12  Orietta's Recipes  2020-01-14 07:53:59
# 13  Orietta's Recipes  2020-01-13 18:15:28
# 14  Orietta's Recipes  2020-01-13 11:43:54
# 15  Orietta's Recipes  2020-01-13 07:54:36
# 16  Orietta's Recipes  2020-01-12 18:10:18
# 17  Orietta's Recipes  2020-01-12 11:38:09
# 18  Orietta's Recipes  2020-01-12 08:07:22
# 19  Orietta's Recipes  2020-01-11 18:53:19
# 20  Orietta's Recipes  2020-01-11 11:30:51
# 21  Orietta's Recipes  2020-01-11 07:57:43
# 22  Orietta's Recipes  2020-01-10 17:55:43
# 23  Orietta's Recipes  2020-01-10 14:05:22
# 24  Orietta's Recipes  2020-01-10 11:28:53
# 25  Orietta's Recipes  2020-01-10 07:03:27
# 26  Orietta's Recipes  2020-01-09 18:18:16
#
#                                                  text   retweet_count  \
# 0   Stasera cena a base di pesce! Tonno alla piast...              15
# 1   Buon pranzo, io oggi pranzo leggero con il mio...              23
# 2   Buongiorno e grazie ancora a tutti per gli aug...              16
# 3   Biscotti delicati di sabbia 😋 ❤️😘🥂🥂🍾.! https:/...              25
# 4   Oggi è il mio compleanno 🎂 🥂 ❤️ amici! Vorrei ...              45
# 5   Io oggi riso integrale con crema di piselli 😋 ...              14
# 6   Oggi ho proprio voglia di qualcosa di buono do...              26
# 7   Buona cena amici, io stasera polpette di halib...              25
# 8   Oggi ho proprio voglia di un piatto di trofie ...              17
# 9   Buongiorno! 😁😘 oggi condivido con voi la mia 😀...              48
# 10  Stasera per cena, involtini di cavolo cinese c...              21
# 11  Oggi pasta con zucchine e primo sale, semplice...              19
# 12  Buongiorno amici 🤗😘🤗😘❤️Chi vuole per colazione...              21
# 13  Stasera come contorno mini carote speziate al ...              12
# 14  Spaghetti con polpo e 'nduja 😋 😋 se non li ave...              27
# 15  Buon inizio settimana a tutti voi,☺️ oggi per ...              27
# 16  La mia cena informale ☺️ con pane semi integra...              15
# 17  Buon pranzo domenicale amici ☺️, spero siate i...              15
# 18  Buongiorno e buona domenica 💕Sto preparando le...              20
# 19  Buona  Pizza a tutti ☺️ ☺️ 😀 🍕🍻 🍕 🍕 #SaturdayM...              30
# 20  Oggi penne all'arrabbiata! 😋 🍷. Con un primo c...              24
# 21  Ben svegliati 💕! Stamattina la mia  colazione ...              17
# 22  Non sapete cosa preparare per cena? Vi do un'i...              14
# 23  Esco a fare due passi e mi rilasso un po' ☕☕ 😘...              13
# 24  Oggi rigatoni con trota salmonata, bottarga di...              19
# 25  Buongiorno! Oggi iniziamo la   giornata 💕 con ...              41
# 26  Stasera per cena propongo 😋 Soufflé di carote ...              18
#
#      favourites_count
# 0                  49
# 1                  67
# 2                  85
# 3                 166
# 4                 482
# 5                  68
# 6                 117
# 7                 104
# 8                  62
# 9                 171
# 10                102
# 11                 74
# 12                127
# 13                 59
# 14                102
# 15                106
# 16                 78
# 17                 94
# 18                111
# 19                179
# 20                116
# 21                 83
# 22                 78
# 23                125
# 24                 60
# 25                152
# 26                 83

# %%
df['text']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/miniconda3/envs/learn/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2896             try:
# -> 2897                 return self._engine.get_loc(key)
#    2898             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'text'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-15-e832ad315372> in <module>
# ----> 1 df['text']
#
# ~/miniconda3/envs/learn/lib/python3.6/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2993             if self.columns.nlevels > 1:
#    2994                 return self._getitem_multilevel(key)
# -> 2995             indexer = self.columns.get_loc(key)
#    2996             if is_integer(indexer):
#    2997                 indexer = [indexer]
#
# ~/miniconda3/envs/learn/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2897                 return self._engine.get_loc(key)
#    2898             except KeyError:
# -> 2899                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2900         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#    2901         if indexer.ndim > 1 or indexer.size > 1:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'text'
